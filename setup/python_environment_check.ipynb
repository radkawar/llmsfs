# %%
from python_environment_check import check_packages, get_requirements_dict

d = get_requirements_dict()
check_packages(d)
# Out:
# [OK] Your Python version is 3.11.15
# [OK] torch 2.5.1
# [OK] jupyterlab 4.6.2
# [OK] tiktoken 0.13.0
# [OK] matplotlib 3.11.1
# [OK] tensorflow 2.18.1
# [OK] tqdm 4.70.0
# [OK] numpy 2.0.2
# [OK] pandas 2.3.3
# [OK] psutil 7.2.2
